# %%
from PIL import Image
from owslib.wms import WebMapService
from pyproj import CRS

# %%
from pyproj import Proj, transform


outProj = Proj(init='epsg:3857') # https://epsg.io/3857

inProj = Proj(init='epsg:4326') # https://epsg.io/4326

arizona_crater=(-111.02278,35.02722)

loc = arizona_crater

x, y = transform(inProj,outProj,loc[0],loc[1])

size=(1000, 1000)
xupper = int(round(x - 5000))
xlower = int(round(x + 5000))
yupper = int(round(y - 5000))
ylower = int(round(y + 5000))

bbox = (xupper, yupper, xlower, ylower)
# Out:
# /opt/anaconda3/envs/research/lib/python3.12/site-packages/pyproj/crs/crs.py:143: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /opt/anaconda3/envs/research/lib/python3.12/site-packages/pyproj/crs/crs.py:143: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# ...

# %%
x,y
# Out:
# (-12358999.336053638, 4167580.8488699957)

# %%
from pyproj import Proj, transform
from PIL import Image
from owslib.wms import WebMapService
from pyproj import CRS

outProj = Proj(init='epsg:3857') # https://epsg.io/3857

inProj = Proj(init='epsg:4326') # https://epsg.io/4326

arizona_crater=(-111.02278,35.02722)

loc = arizona_crater

x, y = loc[0],loc[1]#transform(inProj,outProj,loc[0],loc[1])

size=(1000, 1000)
xupper = int(round(x - 5000))
xlower = int(round(x + 5000))
yupper = int(round(y - 5000))
ylower = int(round(y + 5000))

bbox = (xupper, yupper, xlower, ylower)

wms = WebMapService("https://sh.dataspace.copernicus.eu/ogc/wms/ae776445-caca-44d3-a4e2-6f4e9b575a31")
wms['1_TRUE_COLOR'].styles
res = wms.getmap(   layers=['1_TRUE_COLOR'],
                    styles =['RGB'],
                    srs='EPSG:3857',
                    bbox=bbox,
                    size=size,
                    format='image/jpeg',

                    )
img2 = Image.open(res)
img2
bbox
# Out:
# /opt/anaconda3/envs/research/lib/python3.12/site-packages/pyproj/crs/crs.py:143: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# /opt/anaconda3/envs/research/lib/python3.12/site-packages/pyproj/crs/crs.py:143: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# (-5111, -4965, 4889, 5035)

# %%
from pyproj import Proj, transform

size=(250, 250)
xlower  = xupper + 1000
yupper = ylower - 1000

bbox = (xupper, yupper, xlower, ylower)

# %%
wms = WebMapService("https://sh.dataspace.copernicus.eu/ogc/wms/ae776445-caca-44d3-a4e2-6f4e9b575a31")
wms['1_TRUE_COLOR'].styles
res = wms.getmap(   layers=['1_TRUE_COLOR'],
                    styles =['RGB'],
                    srs='EPSG:3857',
                    bbox=bbox,
                    size=size,
                    format='image/jpeg',

                    )
img2 = Image.open(res)
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>
